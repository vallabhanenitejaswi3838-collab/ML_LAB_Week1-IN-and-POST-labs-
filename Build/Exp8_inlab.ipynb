# %% [markdown]
# # Experiment 8: Artificial Neural Networks using Keras

# %% [markdown]
# ## Task 1: Design and implement Artificial Neural Network architectures using Keras for classification tasks
# *Suggested Dataset: Pima Indians Diabetes Dataset*

# %% [markdown]
# ### Subtask 1.1: Data Acquisition, Imputation, and Feature Scaling
# **Concept:** Import warnings suppression, load the raw Pima Indians dataset, handle missing value zeros using median imputation, standardize the features, and perform a stratified train-test split.

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.impute import SimpleImputer

# %%
# Load Pima Indians Diabetes dataset
pima_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# %%
pima_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
pima_df = pd.read_csv(pima_url, header=None, names=pima_cols)

# %%
# Prevent copy warnings using an explicit copy
X_pima = pima_df[pima_cols[:-1]].copy()

# %%
y_pima = pima_df['Outcome']

# %%
# Mark invalid zeros as NaN placeholders for imputation
cols_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
X_pima[cols_to_impute] = X_pima[cols_to_impute].replace(0, np.nan)

# %%
# Impute and standardize
imputer = SimpleImputer(strategy='median')

# %%
X_imputed = imputer.fit_transform(X_pima)

# %%
scaler = StandardScaler()

# %%
X_pima_scaled = scaler.fit_transform(X_imputed)

# %%
# Stratified train-test split
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(
    X_pima_scaled, y_pima, test_size=0.20, stratify=y_pima, random_state=42
)

# %%
print("Preprocessed Pima dataset shapes:")
print(f"  Training set features: {X_train_p.shape} | Test set features: {X_test_p.shape}")
# Out:
# Preprocessed Pima dataset shapes:
#   Training set features: (614, 8) | Test set features: (154, 8)

# %% [markdown]
# ### Subtask 1.2: Designing Feedforward Neural Network Architectures
# **Concept:** Design a baseline feedforward Artificial Neural Network (ANN) using Keras Sequential API, configuring hidden Dense layers with ReLU activations and a binary Sigmoid output node.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
# Design baseline sequential model
ann_pima = Sequential([
    # Input layer + Hidden layer 1: 16 neurons with ReLU activation
    Dense(16, activation='relu', input_shape=(8,)),
    # Hidden layer 2: 8 neurons with ReLU activation
    Dense(8, activation='relu'),
    # Output layer: 1 neuron with Sigmoid activation for binary classification
    Dense(1, activation='sigmoid')
])

# %%
print("Sequential ANN Architecture established:")
ann_pima.summary()
# Out:
# Sequential ANN Architecture established:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Subtask 1.3: Compiling the Neural Network Model
# **Concept:** Compile the sequential model by defining binary_crossentropy as the loss function, Adam as the optimizer, and accuracy as the primary evaluation metric.

# %%
# Compile the neural network model
ann_pima.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
print("Neural network model compiled successfully.")
# Out:
# Neural network model compiled successfully.

# %% [markdown]
# ### Subtask 1.4: Fitting the Network with Validation Splits
# **Concept:** Train the compiled network on the training set for 50 epochs using a batch size of 16 and a 20% validation split.

# %%
# Fit model and collect training metrics
history_pima = ann_pima.fit(
    X_train_p,
    y_train_p,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5703 - loss: 0.6983 - val_accuracy: 0.5935 - val_loss: 0.6713
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6701 - loss: 0.6467 - val_accuracy: 0.6585 - val_loss: 0.6319
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6802 - loss: 0.6087 - val_accuracy: 0.6748 - val_loss: 0.5993
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6823 - loss: 0.5761 - val_accuracy: 0.6911 - val_loss: 0.5722
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7088 - loss: 0.5498 - val_accuracy: 0.7073 - val_loss: 0.5501
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8147 - loss: 0.3916 - val_accuracy: 0.7886 - val_loss: 0.4415
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8126 - loss: 0.3902 - val_accuracy: 0.7886 - val_loss: 0.4434
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8187 - loss: 0.3899 - val_accuracy: 0.7886 - val_loss: 0.4425
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8147 - loss: 0.3886 - val_accuracy: 0.7886 - val_loss: 0.4414
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.3878 - val_accuracy: 0.7805 - val_loss: 0.4430

# %%
print("\nModel training complete.")
# Out:
# Model training complete.

# %% [markdown]
# ### Subtask 1.5: Evaluating Classifications on Held-out Test Data
# **Concept:** Predict output probabilities on held-out test data, threshold them at 0.5, and evaluate predictions using accuracy, a confusion matrix, and a classification report.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Predict target probabilities
y_pred_probs = ann_pima.predict(X_test_p)
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fa83d16ba60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fa83d16ba60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Threshold probabilities to binary classes (0 or 1)
y_pred_classes = (y_pred_probs >= 0.5).astype(int)

# %%
test_acc = accuracy_score(y_test_p, y_pred_classes)

# %%
print(f"ANN Holdout Test Accuracy: {test_acc * 100:.2f}%\n")

print("--- Classification Report ---")
print(classification_report(y_test_p, y_pred_classes, target_names=['No Diabetes', 'Diabetes']))
# Out:
# ANN Holdout Test Accuracy: 74.03%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#  No Diabetes       0.79      0.82      0.80       100
#     Diabetes       0.64      0.59      0.62        54
#
#     accuracy                           0.74       154
#    macro avg       0.71      0.71      0.71       154
# weighted avg       0.74      0.74      0.74       154

# %%
# Plot confusion matrix
cm_pima = confusion_matrix(y_test_p, y_pred_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm_pima, annot=True, fmt='d', cmap='Blues', xticklabels=['No Diabetes', 'Diabetes'], yticklabels=['No Diabetes', 'Diabetes'])
plt.title("ANN Classification Confusion Matrix - 24EU02062")
plt.show()

# %% [markdown]
# ## Task 2: Train neural network models and analyze learning behavior using suitable evaluation measures
# *Suggested Dataset: Sonar Dataset*

# %% [markdown]
# ### Subtask 2.1: Standard Scaling and High-Dimensional Data Splitting
# **Concept:** Import warnings suppression, load the Sonar dataset, map nominal class labels, standardize features, and perform a stratified split.

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Load Sonar dataset
sonar_url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"

# %%
sonar_features = [f"F_{i}" for i in range(1, 61)]

# %%
sonar_columns = sonar_features + ['Class']

# %%
sonar_df = pd.read_csv(sonar_url, header=None, names=sonar_columns)

# %%
# Encode class: M -> 1, R -> 0
sonar_df['Class_numeric'] = sonar_df['Class'].map({'M': 1, 'R': 0})

# %%
X_sonar = sonar_df[sonar_features]
y_sonar = sonar_df['Class_numeric']

# %%
# Scale features
scaler_sonar = StandardScaler()
X_sonar_scaled = scaler_sonar.fit_transform(X_sonar)

# %%
# Split into train/test sets
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(
    X_sonar_scaled, y_sonar, test_size=0.30, stratify=y_sonar, random_state=42
)

# %%
print("Sonar Training Set Shape:", X_train_s.shape)
print("Sonar Test Set Shape:", X_test_s.shape)
# Out:
# Sonar Training Set Shape: (145, 60)
# Sonar Test Set Shape: (63, 60)

# %% [markdown]
# ### Subtask 2.2: Designing Deep Neural Networks with Dropout Regularization
# **Concept:** Construct a deep multi-layer neural network using Keras and incorporate Dropout layers to prevent overfitting on high-dimensional continuous features.

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
# Design regularized sequential network
ann_sonar = Sequential([
    # Input layer + Dense hidden layer 1
    Dense(64, activation='relu', input_shape=(60,)),
    Dropout(0.3), # Apply 30% dropout rate to mitigate co-adaptation
    # Dense hidden layer 2
    Dense(32, activation='relu'),
    Dropout(0.3), # Apply 30% dropout rate
    # Binary sigmoid output node
    Dense(1, activation='sigmoid')
])

# %%
print("Regularized Sonar ANN Architecture established:")
ann_sonar.summary()
# Out:
# Regularized Sonar ANN Architecture established:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 64)             │         3,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,017 (23.50 KB)
#  Trainable params: 6,017 (23.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Subtask 2.3: Compiling and Training the Sonar Network
# **Concept:** Compile your model with the Adam optimizer, fit it on the Sonar training set for 80 epochs, and collect the training metrics.

# %%
# Compile the model
ann_sonar.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Fit model and collect training metrics
history_sonar = ann_sonar.fit(
    X_train_s,
    y_train_s,
    epochs=80,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.5603 - loss: 0.7144 - val_accuracy: 0.6552 - val_loss: 0.6503
# Epoch 2/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5690 - loss: 0.7163 - val_accuracy: 0.6897 - val_loss: 0.6123
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6034 - loss: 0.6306 - val_accuracy: 0.7241 - val_loss: 0.5841
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6638 - loss: 0.6169 - val_accuracy: 0.7586 - val_loss: 0.5624
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6983 - loss: 0.5452 - val_accuracy: 0.7586 - val_loss: 0.5428
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7155 - loss: 0.5551 - val_accuracy: 0.7586 - val_loss: 0.5192
# Epoch 7/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7414 - loss: 0.5120 - val_accuracy: 0.7931 - val_loss: 0.4996
# Epoch 8/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8017 - loss: 0.4537 - val_accuracy: 0.7931 - val_loss: 0.4812
# Epoch 9/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7845 - loss: 0.4387 - val_accuracy: 0.7931 - val_loss: 0.4648
# Epoch 10/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8448 - loss: 0.4096 - val_accuracy: 0.7931 - val_loss: 0.4491
# Epoch 11/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8190 - loss: 0.3964 - val_accuracy: 0.7931 - val_loss: 0.4357
# Epoch 12/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8534 - loss: 0.3877 - val_accuracy: 0.7931 - val_loss: 0.4216
# Epoch 13/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8707 - loss: 0.3569 - val_accuracy: 0.7931 - val_loss: 0.4096
# Epoch 14/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8621 - loss: 0.3363 - val_accuracy: 0.7931 - val_loss: 0.3985
# Epoch 15/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8276 - loss: 0.3425 - val_accuracy: 0.7931 - val_loss: 0.3974
# Epoch 16/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8621 - loss: 0.3406 - val_accuracy: 0.8276 - val_loss: 0.3919
# Epoch 17/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9224 - loss: 0.2788 - val_accuracy: 0.8276 - val_loss: 0.3806
# Epoch 18/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8707 - loss: 0.2867 - val_accuracy: 0.8276 - val_loss: 0.3694
# Epoch 19/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9224 - loss: 0.2973 - val_accuracy: 0.8276 - val_loss: 0.3613
# Epoch 20/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8966 - loss: 0.2622 - val_accuracy: 0.8276 - val_loss: 0.3561
# Epoch 21/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8966 - loss: 0.2925 - val_accuracy: 0.8276 - val_loss: 0.3541
# Epoch 22/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8966 - loss: 0.2313 - val_accuracy: 0.8276 - val_loss: 0.3553
# Epoch 23/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9397 - loss: 0.2089 - val_accuracy: 0.8276 - val_loss: 0.3566
# Epoch 24/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9052 - loss: 0.2448 - val_accuracy: 0.8276 - val_loss: 0.3548
# Epoch 25/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0487 - val_accuracy: 0.8276 - val_loss: 0.4133
# Epoch 60/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0443 - val_accuracy: 0.8276 - val_loss: 0.4320
# Epoch 61/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 0.7586 - val_loss: 0.4467
# Epoch 62/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0553 - val_accuracy: 0.8276 - val_loss: 0.4514
# Epoch 63/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.8276 - val_loss: 0.4460
# Epoch 64/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0515 - val_accuracy: 0.8276 - val_loss: 0.4501
# Epoch 65/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.8276 - val_loss: 0.4520
# Epoch 66/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0535 - val_accuracy: 0.7931 - val_loss: 0.4611
# Epoch 67/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9741 - loss: 0.0481 - val_accuracy: 0.7931 - val_loss: 0.4637
# Epoch 68/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0299 - val_accuracy: 0.7931 - val_loss: 0.4648
# Epoch 69/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9914 - loss: 0.0485 - val_accuracy: 0.7931 - val_loss: 0.4697
# Epoch 70/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9828 - loss: 0.0394 - val_accuracy: 0.7931 - val_loss: 0.4811
# Epoch 71/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.7931 - val_loss: 0.4898
# Epoch 72/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0360 - val_accuracy: 0.7931 - val_loss: 0.4892
# Epoch 73/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0280 - val_accuracy: 0.7931 - val_loss: 0.4903
# Epoch 74/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9914 - loss: 0.0326 - val_accuracy: 0.7931 - val_loss: 0.5025
# Epoch 75/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9828 - loss: 0.0374 - val_accuracy: 0.7931 - val_loss: 0.5070
# Epoch 76/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 0.7931 - val_loss: 0.5149
# Epoch 77/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.7931 - val_loss: 0.5315
# Epoch 78/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.7931 - val_loss: 0.5464
# Epoch 79/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.7931 - val_loss: 0.5563
# Epoch 80/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9914 - loss: 0.0343 - val_accuracy: 0.7931 - val_loss: 0.5516

# %%
print("\nModel training complete.")
# Out:
# Model training complete.

# %% [markdown]
# ### Subtask 2.4: Plotting Loss and Accuracy Learning Curves
# **Concept:** Plot the training versus validation loss and training versus validation accuracy curves across epochs to analyze model convergence and detect overfitting.

# %%
import matplotlib.pyplot as plt

# %%
# Extract metrics from training history
train_loss = history_sonar.history['loss']
val_loss = history_sonar.history['val_loss']
train_acc = history_sonar.history['accuracy']
val_acc = history_sonar.history['val_accuracy']
epochs_range = range(1, len(train_loss) + 1)

# Plot loss curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(epochs_range, train_loss, 'b-', label='Training Loss')
axes[0].plot(epochs_range, val_loss, 'r-', label='Validation Loss')
axes[0].set_title("24EU02062-Training vs. Validation Loss")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")
axes[0].legend()

# Plot accuracy curves
axes[1].plot(epochs_range, train_acc, 'b-', label='Training Accuracy')
axes[1].plot(epochs_range, val_acc, 'r-', label='Validation Accuracy')
axes[1].set_title("24EU02062-Training vs. Validation Accuracy")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Subtask 2.5: Evaluating Classification Metrics and ROC-AUC Curves
# **Concept:** Evaluate predictions on the test set and plot the Receiver Operating Characteristic (ROC) curve to calculate the Area Under the Curve (AUC).

# %%
from sklearn.metrics import classification_report, roc_curve, auc

# %%
import matplotlib.pyplot as plt

# %%
# Predict probabilities on test set
sonar_probs = ann_sonar.predict(X_test_s)[:, 0]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
sonar_preds = (sonar_probs >= 0.5).astype(int)

# %%
# Print classification report
print("--- Classification Report (Sonar Test Set) ---")
print(classification_report(y_test_s, sonar_preds, target_names=['Rock (0)', 'Mine (1)']))
# Out:
# --- Classification Report (Sonar Test Set) ---
#               precision    recall  f1-score   support
#
#     Rock (0)       0.82      0.93      0.87        29
#     Mine (1)       0.93      0.82      0.88        34
#
#     accuracy                           0.87        63
#    macro avg       0.88      0.88      0.87        63
# weighted avg       0.88      0.87      0.87        63

# %%
# Compute ROC curve coordinates and AUC score
fpr, tpr, _ = roc_curve(y_test_s, sonar_probs)
roc_auc = auc(fpr, tpr)

# %%
# Plot the ROC curve
plt.figure(figsize=(6, 4.5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title("24EU02062-ROC Curve: Sonar Classification")
plt.xlabel("False Positive Rate (1 - Specificity)")
plt.ylabel("True Positive Rate (Sensitivity)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Task 3: Perform hyperparameter optimization to improve neural network performance and generalization
# *Continuous Optimization and Regularization on Pima Indians Dataset*

# %% [markdown]
# ### Subtask 3.1: Building a Parameterized Network Builder Function
# **Concept:** Construct a flexible, parameter-driven builder function that lets you compile an ANN model with different optimizer choices.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
# Define parameterized builder function
def build_ann_model(optimizer_name='adam'):
    model = Sequential([
        Dense(32, activation='relu', input_shape=(8,)),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=optimizer_name,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
print("Modular ANN model builder function established.")
# Out:
# Modular ANN model builder function established.

# %% [markdown]
# ### Subtask 3.2: Tuning Convergence Speeds manually
# **Concept:** Run a manual search loop across different optimizers (Adam, SGD, RMSprop) to compare training loss convergence.

# %%
optimizers = ['adam', 'sgd', 'rmsprop']
history_records = {}

# %%
print("--- Running Optimizer Search ---")
for opt in optimizers:
    print(f"Training network using: {opt}...")
    temp_model = build_ann_model(optimizer_name=opt)

    # Fit for 30 epochs
    hist = temp_model.fit(
        X_train_p,
        y_train_p,
        validation_split=0.2,
        epochs=30,
        batch_size=16,
        verbose=0
    )
    history_records[opt] = hist.history['loss']
# Out:
# --- Running Optimizer Search ---
# Training network using: adam...
# Training network using: sgd...
# Training network using: rmsprop...

# %%
print("Tuning loop complete.")
# Out:
# Tuning loop complete.

# %% [markdown]
# ### Subtask 3.3: Comparing Optimizer Loss Trajectories
# **Concept:** Plot the training loss trajectories across your selected optimizers to evaluate and select the fastest converging solver.

# %%
import matplotlib.pyplot as plt

# %%
# Plot optimizer training loss profiles
plt.figure(figsize=(7, 4.5))
for opt in optimizers:
    plt.plot(range(1, 31), history_records[opt], label=f"Optimizer: {opt.upper()}")

plt.title("24EU02062-Training Loss Convergence Comparison")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Subtask 3.4: Implementing Early Stopping Regularization
# **Concept:** Set up an EarlyStopping callback to automatically halt training and restore the best weights when the validation loss stops improving.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Configure EarlyStopping callback
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# %%
# Build model with the optimal optimizer found
tuned_model = build_ann_model(optimizer_name='adam')

# %%
print("Training model with Early Stopping...")
# Out:
# Training model with Early Stopping...

# %%
# Fit model for up to 100 epochs
history_tuned = tuned_model.fit(
    X_train_p,
    y_train_p,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4257 - loss: 0.8018 - val_accuracy: 0.5691 - val_loss: 0.6804
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6395 - loss: 0.6643 - val_accuracy: 0.6911 - val_loss: 0.5993
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6945 - loss: 0.5980 - val_accuracy: 0.7317 - val_loss: 0.5494
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.5469 - val_accuracy: 0.7724 - val_loss: 0.5043
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.5045 - val_accuracy: 0.7886 - val_loss: 0.4726
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7760 - loss: 0.4758 - val_accuracy: 0.8049 - val_loss: 0.4512
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7821 - loss: 0.4577 - val_accuracy: 0.8049 - val_loss: 0.4404
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7923 - loss: 0.4469 - val_accuracy: 0.7967 - val_loss: 0.4313
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7882 - loss: 0.4433 - val_accuracy: 0.8049 - val_loss: 0.4278
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7902 - loss: 0.4365 - val_accuracy: 0.8049 - val_loss: 0.4243
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7882 - loss: 0.4348 - val_accuracy: 0.8049 - val_loss: 0.4253
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7902 - loss: 0.4304 - val_accuracy: 0.8130 - val_loss: 0.4250
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7923 - loss: 0.4279 - val_accuracy: 0.8130 - val_loss: 0.4223
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7963 - loss: 0.4257 - val_accuracy: 0.8130 - val_loss: 0.4200
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7963 - loss: 0.4244 - val_accuracy: 0.8130 - val_loss: 0.4247
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7943 - loss: 0.4214 - val_accuracy: 0.8130 - val_loss: 0.4234
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.4203 - val_accuracy: 0.8211 - val_loss: 0.4225
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4198 - val_accuracy: 0.8211 - val_loss: 0.4224
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4160 - val_accuracy: 0.8130 - val_loss: 0.4234
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4143 - val_accuracy: 0.8130 - val_loss: 0.4250
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7984 - loss: 0.4129 - val_accuracy: 0.8211 - val_loss: 0.4218
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7943 - loss: 0.4118 - val_accuracy: 0.8211 - val_loss: 0.4225
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7984 - loss: 0.4097 - val_accuracy: 0.8130 - val_loss: 0.4273
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8024 - loss: 0.4090 - val_accuracy: 0.8211 - val_loss: 0.4251
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %% [markdown]
# ### Subtask 3.5: Evaluating the Tuned, Regularized Model
# **Concept:** Compare the final test accuracy of the tuned, early-stopped model against the baseline model trained with fixed epochs in Task 1.

# %%
from sklearn.metrics import accuracy_score

# %%
# Evaluate baseline model from Task 1
baseline_accuracy = ann_pima.evaluate(X_test_p, y_test_p, verbose=0)[1]

# %%
# Evaluate the tuned, early-stopped model
tuned_accuracy = tuned_model.evaluate(X_test_p, y_test_p, verbose=0)[1]

# %%
comparison_df = pd.DataFrame({
    'Model Configuration': ['Baseline ANN (Fixed 50 Epochs)', 'Tuned ANN (with Early Stopping)'],
    'Test Accuracy (%)': [baseline_accuracy * 100, tuned_accuracy * 100],
    'Epochs Trained': [50, len(history_tuned.history['loss'])]
})

# %%
print("--- Final Performance Comparison ---")
print(comparison_df.to_string(index=False))
# Out:
# --- Final Performance Comparison ---
#             Model Configuration  Test Accuracy (%)  Epochs Trained
#  Baseline ANN (Fixed 50 Epochs)          74.025977              50
# Tuned ANN (with Early Stopping)          70.129871              24
